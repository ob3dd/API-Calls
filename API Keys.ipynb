# %% [markdown]
# ## Imports

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
# os - for saving and loading files
# json - to work with json files
# math - to round up results
# time - to add a short pause to not overwhelm the server
import os, json, math, time

# to make yelpapi calls
from yelpapi import YelpAPI

# progress bar from tqdm_notebook
from tqdm.notebook import tqdm_notebook

# %%
# !pip install yelpapi
# !pip install tqdm
# Out:
# Requirement already satisfied: yelpapi in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (2.5.0)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (from yelpapi) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (2022.9.24)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (1.26.13)
# Requirement already satisfied: tqdm in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (4.64.1)

# %%
with open('/Users/obed/.secret/yelp_api.json', 'r') as f:
    login = json.load(f)

# %%
login.keys()
# Out:
# dict_keys(['Client-ID', 'API Key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['API Key'], timeout_s = 5.0)
yelp

# %%
# set our API call parameters and filename before the first call
location = 'Hampton, GA 30228'
term = 'jollof'

# %%
location.split(',')[0]
# Out:
# 'Hampton'

# %%
## Specify folder for saving data
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)
# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/Hampton-jollof.json'

# %% [markdown]
# ### Check if Json File exists and Create it if it doesn't

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:    
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON folder name is not empty:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
          json.dump([], f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Hampton-jollof.json already exists.

# %%
os.path.isfile(JSON_FILE)
# Out:
# True

# %%
# using my yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term = term, location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 17

# %%
# Check what regions our results are located in
results['region']
# Out:
# {'center': {'longitude': -84.2816162109375, 'latitude': 33.381848848303875}}

# %%
# Check what businesses have our results
results['businesses']
# Out:
# [{'id': 'ARc6SiubmOBztQqScaZYHQ',
#   'alias': 'boniks-african-cuisine-forest-park',
#   'name': 'Boniks African Cuisine',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/u3F3mOEeSLefaOqHRv8vPA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boniks-african-cuisine-forest-park?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 25,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 33.63320670469158, 'longitude': -84.3578236},
#   'transactions': [],
#   'location': {'address1': '4452 Jonesboro Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Forest Park',
#    'zip_code': '30297',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['4452 Jonesboro Rd', 'Forest Park, GA 30297']},
#   'phone': '+14049753831',
#   'display_phone': '(404) 975-3831',
#   'distance': 28828.941198960652},
#  {'id': 'cZLAslcv5GjWVavKm3ZxDQ',
#   'alias': 'west-african-dishes-riverdale',
#   'name': 'West African Dishes',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AhBjFcCeS8d8vJaMMx78og/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/west-african-dishes-riverdale?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 5,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 33.57459735795027,
#    'longitude': -84.41539943218231},
#   'transactions': [],
#   'location': {'address1': '6597 Church St',
#    'address2': '',
#    'address3': None,
#    'city': 'Riverdale',
#    'zip_code': '30274',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['6597 Church St', 'Riverdale, GA 30274']},
#   'phone': '+14044293317',
#   'display_phone': '(404) 429-3317',
#   'distance': 24765.21668790886},
#  {'id': 'MzwJ-_Vg5ekow6DKqjakbw',
#   'alias': 'brothers-restaurant-atlanta-2',
#   'name': 'Brothers Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PY3ZUbZVF0bE6g_TA4oq5Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brothers-restaurant-atlanta-2?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 2,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 33.606391, 'longitude': -84.4357011},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '5461 Riverdale Rd',
#    'address2': None,
#    'address3': None,
#    'city': 'Atlanta',
#    'zip_code': '30349',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['5461 Riverdale Rd', 'Atlanta, GA 30349']},
#   'phone': '+16786046680',
#   'display_phone': '(678) 604-6680',
#   'distance': 28783.492045193547},
#  {'id': 'hVM9MYthDhQeFUMhftUg_Q',
#   'alias': 'touray-kunda-cafe-atlanta',
#   'name': 'Touray Kunda Cafe',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5k0Vilil_WiqN0EamQlw7A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/touray-kunda-cafe-atlanta?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 4,
#   'categories': [{'alias': 'african', 'title': 'African'},
#    {'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 33.615469, 'longitude': -84.471191},
#   'transactions': ['delivery'],
#   'location': {'address1': '5134 Old National Hwy',
#    'address2': '',
#    'address3': None,
#    'city': 'Atlanta',
#    'zip_code': '30349',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['5134 Old National Hwy', 'Atlanta, GA 30349']},
#   'phone': '+14042286544',
#   'display_phone': '(404) 228-6544',
#   'distance': 31365.90924160381},
#  {'id': 'DavpiHogGrgMpN46bxsx6w',
#   'alias': 'buka-2-restaurant-and-lounge-atlanta',
#   'name': 'Buka 2 Restaurant & Lounge',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2fzu_3drGjUQxlAoxbom6g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/buka-2-restaurant-and-lounge-atlanta?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 38,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 33.6066208, 'longitude': -84.4349213},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '5436 Riverdale Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Atlanta',
#    'zip_code': '30349',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['5436 Riverdale Rd', 'Atlanta, GA 30349']},
#   'phone': '+16785195443',
#   'display_phone': '(678) 519-5443',
#   'distance': 28746.707011112114},
#  {'id': 's27OJjzyZuLe2cAUpa395w',
#   'alias': 'mama-put-restaurant-fayetteville',
#   'name': 'Mama Put Restaurant',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/msj862mTiK57bY55wOm-2g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mama-put-restaurant-fayetteville?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 10,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 33.512312, 'longitude': -84.430294},
#   'transactions': [],
#   'location': {'address1': '101 Kenwood Rd',
#    'address2': 'Ste 28',
#    'address3': '',
#    'city': 'Fayetteville',
#    'zip_code': '30214',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['101 Kenwood Rd', 'Ste 28', 'Fayetteville, GA 30214']},
#   'phone': '+16782712011',
#   'display_phone': '(678) 271-2011',
#   'distance': 20018.31281514213},
#  {'id': 'zuEk9L0WD-1WOvr3M-VRpA',
#   'alias': 'musulyns-international-restaurant-covington',
#   'name': "Musulyn's International Restaurant",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0dKTmnBYuHRIu6L_kUs2fQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/musulyns-international-restaurant-covington?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 13,
#   'categories': [{'alias': 'soulfood', 'title': 'Soul Food'},
#    {'alias': 'african', 'title': 'African'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 33.604471, 'longitude': -83.8734289},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '6129 US-278 NW',
#    'address2': 'Ste 4',
#    'address3': '',
#    'city': 'Covington',
#    'zip_code': '30014',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['6129 US-278 NW', 'Ste 4', 'Covington, GA 30014']},
#   'phone': '+14704441135',
#   'display_phone': '(470) 444-1135',
#   'distance': 45227.46431044542},
#  {'id': 'jnkRjphKZMics4d256speA',
#   'alias': 'ty-lexine-cuisine-jonesboro',
#   'name': 'Ty-Lexine Cuisine',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KQt2AW1J0Gl10I6d9TY6SQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ty-lexine-cuisine-jonesboro?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 3,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 33.5217423706404,
#    'longitude': -84.3627944999892},
#   'transactions': [],
#   'location': {'address1': '8558 Tara Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Jonesboro',
#    'zip_code': '30236',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['8558 Tara Blvd', 'Jonesboro, GA 30236']},
#   'phone': '+16784893185',
#   'display_phone': '(678) 489-3185',
#   'distance': 17282.725187408127},
#  {'id': 'gpOglAl0b1e1JLxdc8Gpdg',
#   'alias': 'bamba-cuisine-atlanta',
#   'name': 'Bamba Cuisine',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iRqKp8skZYSATPN4XEWWjw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bamba-cuisine-atlanta?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 71,
#   'categories': [{'alias': 'senegalese', 'title': 'Senegalese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.690039, 'longitude': -84.509568},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3700 Campbellton Rd SW',
#    'address2': 'suite1',
#    'address3': '',
#    'city': 'Atlanta',
#    'zip_code': '30311',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['3700 Campbellton Rd SW',
#     'suite1',
#     'Atlanta, GA 30311']},
#   'phone': '+16787059683',
#   'display_phone': '(678) 705-9683',
#   'distance': 40258.59057967477},
#  {'id': 'FuQExkWBNIYRXShoP9eiog',
#   'alias': 'moyo-grill-and-bar-restaurant-forest-park',
#   'name': 'Moyo Grill & Bar Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/beh1MbazJ4J_-hCDyQBtYg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/moyo-grill-and-bar-restaurant-forest-park?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 13,
#   'categories': [{'alias': 'african', 'title': 'African'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 33.61512, 'longitude': -84.4012},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '5116 GA-85',
#    'address2': None,
#    'address3': '',
#    'city': 'Forest Park',
#    'zip_code': '30297',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['5116 GA-85', 'Forest Park, GA 30297']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 28206.20119495082},
#  {'id': 'Ph9CC8gaPyhaeZX3oxTYrg',
#   'alias': 'saint-louis-cuisine-atlanta',
#   'name': 'Saint-Louis Cuisine',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SEyerBpyIx5scqRoV2PT1g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/saint-louis-cuisine-atlanta?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 10,
#   'categories': [{'alias': 'senegalese', 'title': 'Senegalese'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 33.6003708988768, 'longitude': -84.427568118636},
#   'transactions': ['delivery'],
#   'location': {'address1': '5658 Riverdale Rd',
#    'address2': 'Ste V',
#    'address3': None,
#    'city': 'Atlanta',
#    'zip_code': '30349',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['5658 Riverdale Rd', 'Ste V', 'Atlanta, GA 30349']},
#   'phone': '+16784897559',
#   'display_phone': '(678) 489-7559',
#   'distance': 27813.715610531824},
#  {'id': 'uNiTLrArIMnexNUG8KZJDQ',
#   'alias': 'olyzubbys-kitchen-atlanta',
#   'name': 'Olyzubbys Kitchen',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/by8VYqDi92qLY1UVXFvn1Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/olyzubbys-kitchen-atlanta?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 8,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.6238365, 'longitude': -84.4744492},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '4813 Old National Hwy',
#    'address2': None,
#    'address3': '',
#    'city': 'Atlanta',
#    'zip_code': '30337',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['4813 Old National Hwy', 'Atlanta, GA 30337']},
#   'phone': '+16787935565',
#   'display_phone': '(678) 793-5565',
#   'distance': 32385.630716190582},
#  {'id': 'C9MAykNOCCLt9eN5XriPtg',
#   'alias': 'manding-cafe-atlanta',
#   'name': 'Manding Cafe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/v6ZbqtZ718qDTZK9HqrZ8w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/manding-cafe-atlanta?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 5,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 33.6150816, 'longitude': -84.47424889999999},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '5145 Old National Hwy College Park',
#    'address2': '',
#    'address3': '',
#    'city': 'Atlanta',
#    'zip_code': '30349',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['5145 Old National Hwy College Park',
#     'Atlanta, GA 30349']},
#   'phone': '+16785100911',
#   'display_phone': '(678) 510-0911',
#   'distance': 31490.226351142624},
#  {'id': '78gpVGATiNZRutpA86whfQ',
#   'alias': 'broni-home-taste-restaurant-atlanta',
#   'name': 'Broni Home Taste Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-NUF-49j2-lNxEO8ZmoOyw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/broni-home-taste-restaurant-atlanta?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 22,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 33.623836, 'longitude': -84.4766979},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '4841 Old National Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Atlanta',
#    'zip_code': '30337',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['4841 Old National Hwy', 'Atlanta, GA 30337']},
#   'phone': '+14049482169',
#   'display_phone': '(404) 948-2169',
#   'distance': 32422.27267705874},
#  {'id': 'K_6zSW1thfudWYnQnSmvSQ',
#   'alias': 'nema-kitchen-atlanta',
#   'name': 'Nema Kitchen',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8_0KLFKcDu-b2u6orGCO_Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nema-kitchen-atlanta?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 10,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 33.698215, 'longitude': -84.483722},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '2905 Campbellton Rd SW',
#    'address2': None,
#    'address3': '',
#    'city': 'Atlanta',
#    'zip_code': '30311',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['2905 Campbellton Rd SW', 'Atlanta, GA 30311']},
#   'phone': '+14705755505',
#   'display_phone': '(470) 575-5505',
#   'distance': 39869.34902429198},
#  {'id': 'dq1hK8HctLdK43o3wROjlg',
#   'alias': 'africa-resturant-and-lounge-riverdale',
#   'name': 'Africa Resturant and  Lounge',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VvK79c8Cju_X9IWSNAUxKw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/africa-resturant-and-lounge-riverdale?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 16,
#   'categories': [{'alias': 'african', 'title': 'African'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'hookah_bars', 'title': 'Hookah Bars'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 33.580859, 'longitude': -84.410956},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '6380 GA 85',
#    'address2': '',
#    'address3': None,
#    'city': 'Riverdale',
#    'zip_code': '30274',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['6380 GA 85', 'Riverdale, GA 30274']},
#   'phone': '+16789615878',
#   'display_phone': '(678) 961-5878',
#   'distance': 25172.03771651674},
#  {'id': 'h18B4BtBXJlyIWCHTmLeng',
#   'alias': 'nations-cafe-hapeville',
#   'name': 'Nations Cafe',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iR9mMD7nuaZD9Re46L8EOQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nations-cafe-hapeville?adjust_creative=q2CkjCrzf_Z7x-wy1RQ60A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q2CkjCrzf_Z7x-wy1RQ60A',
#   'review_count': 8,
#   'categories': [{'alias': 'african', 'title': 'African'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 33.664288, 'longitude': -84.408968},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '3293 Dogwood Dr',
#    'address2': '',
#    'address3': None,
#    'city': 'Hapeville',
#    'zip_code': '30354',
#    'country': 'US',
#    'state': 'GA',
#    'display_address': ['3293 Dogwood Dr', 'Hapeville, GA 30354']},
#   'phone': '+14042286866',
#   'display_phone': '(404) 228-6866',
#   'distance': 33549.47173073716}]

# %%
## How many results total?
pd.DataFrame(results['businesses'])
# Out:
#                         id                                        alias  \
# 0   ARc6SiubmOBztQqScaZYHQ           boniks-african-cuisine-forest-park
# 1   cZLAslcv5GjWVavKm3ZxDQ                west-african-dishes-riverdale
# 2   MzwJ-_Vg5ekow6DKqjakbw                brothers-restaurant-atlanta-2
# 3   hVM9MYthDhQeFUMhftUg_Q                    touray-kunda-cafe-atlanta
# 4   DavpiHogGrgMpN46bxsx6w         buka-2-restaurant-and-lounge-atlanta
# 5   s27OJjzyZuLe2cAUpa395w             mama-put-restaurant-fayetteville
# 6   zuEk9L0WD-1WOvr3M-VRpA  musulyns-international-restaurant-covington
# 7   jnkRjphKZMics4d256speA                  ty-lexine-cuisine-jonesboro
# 8   gpOglAl0b1e1JLxdc8Gpdg                        bamba-cuisine-atlanta
# 9   FuQExkWBNIYRXShoP9eiog    moyo-grill-and-bar-restaurant-forest-park
# 10  Ph9CC8gaPyhaeZX3oxTYrg                  saint-louis-cuisine-atlanta
# 11  uNiTLrArIMnexNUG8KZJDQ                    olyzubbys-kitchen-atlanta
# 12  C9MAykNOCCLt9eN5XriPtg                         manding-cafe-atlanta
# 13  78gpVGATiNZRutpA86whfQ          broni-home-taste-restaurant-atlanta
# 14  K_6zSW1thfudWYnQnSmvSQ                         nema-kitchen-atlanta
# 15  dq1hK8HctLdK43o3wROjlg        africa-resturant-and-lounge-riverdale
# 16  h18B4BtBXJlyIWCHTmLeng                       nations-cafe-hapeville
#
#                                   name  \
# 0               Boniks African Cuisine
# 1                  West African Dishes
# 2                  Brothers Restaurant
# 3                    Touray Kunda Cafe
# 4           Buka 2 Restaurant & Lounge
# 5                  Mama Put Restaurant
# 6   Musulyn's International Restaurant
# 7                    Ty-Lexine Cuisine
# 8                        Bamba Cuisine
# 9          Moyo Grill & Bar Restaurant
# 10                 Saint-Louis Cuisine
# 11                   Olyzubbys Kitchen
# 12                        Manding Cafe
# 13         Broni Home Taste Restaurant
# 14                        Nema Kitchen
# 15        Africa Resturant and  Lounge
# 16                        Nations Cafe
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/u3F3mO...      False
# 1   https://s3-media4.fl.yelpcdn.com/bphoto/AhBjFc...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/PY3ZUb...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/5k0Vil...      False
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/2fzu_3...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/msj862...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/0dKTmn...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/KQt2AW...      False
# 8   https://s3-media1.fl.yelpcdn.com/bphoto/iRqKp8...      False
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/beh1Mb...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/SEyerB...      False
# 11  https://s3-media3.fl.yelpcdn.com/bphoto/by8VYq...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/v6Zbqt...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/-NUF-4...      False
# 14  https://s3-media4.fl.yelpcdn.com/bphoto/8_0KLF...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/VvK79c...      False
# 16  https://s3-media1.fl.yelpcdn.com/bphoto/iR9mMD...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/boniks-african-cuisin...            25
# 1   https://www.yelp.com/biz/west-african-dishes-r...             5
# 2   https://www.yelp.com/biz/brothers-restaurant-a...             2
# 3   https://www.yelp.com/biz/touray-kunda-cafe-atl...             4
# 4   https://www.yelp.com/biz/buka-2-restaurant-and...            38
# 5   https://www.yelp.com/biz/mama-put-restaurant-f...            10
# 6   https://www.yelp.com/biz/musulyns-internationa...            13
# 7   https://www.yelp.com/biz/ty-lexine-cuisine-jon...             3
# 8   https://www.yelp.com/biz/bamba-cuisine-atlanta...            71
# 9   https://www.yelp.com/biz/moyo-grill-and-bar-re...            13
# 10  https://www.yelp.com/biz/saint-louis-cuisine-a...            10
# 11  https://www.yelp.com/biz/olyzubbys-kitchen-atl...             8
# 12  https://www.yelp.com/biz/manding-cafe-atlanta?...             5
# 13  https://www.yelp.com/biz/broni-home-taste-rest...            22
# 14  https://www.yelp.com/biz/nema-kitchen-atlanta?...            10
# 15  https://www.yelp.com/biz/africa-resturant-and-...            16
# 16  https://www.yelp.com/biz/nations-cafe-hapevill...             8
#
#                                            categories  rating  \
# 0          [{'alias': 'african', 'title': 'African'}]     3.0
# 1          [{'alias': 'african', 'title': 'African'}]     5.0
# 2          [{'alias': 'african', 'title': 'African'}]     5.0
# 3   [{'alias': 'african', 'title': 'African'}, {'a...     5.0
# 4          [{'alias': 'african', 'title': 'African'}]     2.5
# 5          [{'alias': 'african', 'title': 'African'}]     3.5
# 6   [{'alias': 'soulfood', 'title': 'Soul Food'}, ...     5.0
# 7          [{'alias': 'african', 'title': 'African'}]     3.0
# 8    [{'alias': 'senegalese', 'title': 'Senegalese'}]     4.0
# 9   [{'alias': 'african', 'title': 'African'}, {'a...     3.5
# 10   [{'alias': 'senegalese', 'title': 'Senegalese'}]     5.0
# 11         [{'alias': 'african', 'title': 'African'}]     4.0
# 12         [{'alias': 'african', 'title': 'African'}]     5.0
# 13         [{'alias': 'african', 'title': 'African'}]     3.5
# 14         [{'alias': 'african', 'title': 'African'}]     3.5
# 15  [{'alias': 'african', 'title': 'African'}, {'a...     2.5
# 16  [{'alias': 'african', 'title': 'African'}, {'a...     2.5
#
#                                           coordinates        transactions  \
# 0   {'latitude': 33.63320670469158, 'longitude': -...                  []
# 1   {'latitude': 33.57459735795027, 'longitude': -...                  []
# 2   {'latitude': 33.606391, 'longitude': -84.4357011}  [delivery, pickup]
# 3    {'latitude': 33.615469, 'longitude': -84.471191}          [delivery]
# 4   {'latitude': 33.6066208, 'longitude': -84.4349...  [delivery, pickup]
# 5    {'latitude': 33.512312, 'longitude': -84.430294}                  []
# 6   {'latitude': 33.604471, 'longitude': -83.8734289}  [delivery, pickup]
# 7   {'latitude': 33.5217423706404, 'longitude': -8...                  []
# 8    {'latitude': 33.690039, 'longitude': -84.509568}  [delivery, pickup]
# 9       {'latitude': 33.61512, 'longitude': -84.4012}  [delivery, pickup]
# 10  {'latitude': 33.6003708988768, 'longitude': -8...          [delivery]
# 11  {'latitude': 33.6238365, 'longitude': -84.4744...  [delivery, pickup]
# 12  {'latitude': 33.6150816, 'longitude': -84.4742...  [delivery, pickup]
# 13  {'latitude': 33.623836, 'longitude': -84.4766979}  [delivery, pickup]
# 14   {'latitude': 33.698215, 'longitude': -84.483722}  [delivery, pickup]
# 15   {'latitude': 33.580859, 'longitude': -84.410956}  [delivery, pickup]
# 16   {'latitude': 33.664288, 'longitude': -84.408968}  [delivery, pickup]
#
#                                              location         phone  \
# 0   {'address1': '4452 Jonesboro Rd', 'address2': ...  +14049753831
# 1   {'address1': '6597 Church St', 'address2': '',...  +14044293317
# 2   {'address1': '5461 Riverdale Rd', 'address2': ...  +16786046680
# 3   {'address1': '5134 Old National Hwy', 'address...  +14042286544
# 4   {'address1': '5436 Riverdale Rd', 'address2': ...  +16785195443
# 5   {'address1': '101 Kenwood Rd', 'address2': 'St...  +16782712011
# 6   {'address1': '6129 US-278 NW', 'address2': 'St...  +14704441135
# 7   {'address1': '8558 Tara Blvd', 'address2': '',...  +16784893185
# 8   {'address1': '3700 Campbellton Rd SW', 'addres...  +16787059683
# 9   {'address1': '5116 GA-85', 'address2': None, '...
# 10  {'address1': '5658 Riverdale Rd', 'address2': ...  +16784897559
# 11  {'address1': '4813 Old National Hwy', 'address...  +16787935565
# 12  {'address1': '5145 Old National Hwy College Pa...  +16785100911
# 13  {'address1': '4841 Old National Hwy', 'address...  +14049482169
# 14  {'address1': '2905 Campbellton Rd SW', 'addres...  +14705755505
# 15  {'address1': '6380 GA 85', 'address2': '', 'ad...  +16789615878
# 16  {'address1': '3293 Dogwood Dr', 'address2': ''...  +14042286866
#
#      display_phone      distance price
# 0   (404) 975-3831  28828.941199   NaN
# 1   (404) 429-3317  24765.216688   NaN
# 2   (678) 604-6680  28783.492045   NaN
# 3   (404) 228-6544  31365.909242   NaN
# 4   (678) 519-5443  28746.707011    $$
# 5   (678) 271-2011  20018.312815   NaN
# 6   (470) 444-1135  45227.464310   NaN
# 7   (678) 489-3185  17282.725187   NaN
# 8   (678) 705-9683  40258.590580    $$
# 9                   28206.201195   NaN
# 10  (678) 489-7559  27813.715611   NaN
# 11  (678) 793-5565  32385.630716    $$
# 12  (678) 510-0911  31490.226351   NaN
# 13  (404) 948-2169  32422.272677   NaN
# 14  (470) 575-5505  39869.349024   NaN
# 15  (678) 961-5878  25172.037717   NaN
# 16  (404) 228-6866  33549.471731   NaN

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 17

# %%
(results['total'])/ results_per_page
# Out:
# 1.0

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 1

# %% [markdown]
# ### Make API Call

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    ## The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        ## save number of results to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location = location, term = term,
                                   offset = n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)

            
    ## What to do if we get an error/exception.
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### Open the Final JSON File with Pandas

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                                 alias  \
# 0  cZLAslcv5GjWVavKm3ZxDQ         west-african-dishes-riverdale
# 1  MzwJ-_Vg5ekow6DKqjakbw         brothers-restaurant-atlanta-2
# 2  hVM9MYthDhQeFUMhftUg_Q             touray-kunda-cafe-atlanta
# 3  DavpiHogGrgMpN46bxsx6w  buka-2-restaurant-and-lounge-atlanta
# 4  s27OJjzyZuLe2cAUpa395w      mama-put-restaurant-fayetteville
#
#                          name  \
# 0         West African Dishes
# 1         Brothers Restaurant
# 2           Touray Kunda Cafe
# 3  Buka 2 Restaurant & Lounge
# 4         Mama Put Restaurant
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/AhBjFc...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/PY3ZUb...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/5k0Vil...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/2fzu_3...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/msj862...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/west-african-dishes-r...             5
# 1  https://www.yelp.com/biz/brothers-restaurant-a...             2
# 2  https://www.yelp.com/biz/touray-kunda-cafe-atl...             4
# 3  https://www.yelp.com/biz/buka-2-restaurant-and...            38
# 4  https://www.yelp.com/biz/mama-put-restaurant-f...            10
#
#                                           categories  rating  \
# 0         [{'alias': 'african', 'title': 'African'}]     5.0
# 1         [{'alias': 'african', 'title': 'African'}]     5.0
# 2  [{'alias': 'african', 'title': 'African'}, {'a...     5.0
# 3         [{'alias': 'african', 'title': 'African'}]     2.5
# 4         [{'alias': 'african', 'title': 'African'}]     3.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 33.57459735795027, 'longitude': -...                  []
# 1  {'latitude': 33.606391, 'longitude': -84.4357011}  [delivery, pickup]
# 2   {'latitude': 33.615469, 'longitude': -84.471191}          [delivery]
# 3  {'latitude': 33.6066208, 'longitude': -84.4349...  [delivery, pickup]
# 4   {'latitude': 33.512312, 'longitude': -84.430294}                  []
#
#                                             location         phone  \
# 0  {'address1': '6597 Church St', 'address2': '',...  +14044293317
# 1  {'address1': '5461 Riverdale Rd', 'address2': ...  +16786046680
# 2  {'address1': '5134 Old National Hwy', 'address...  +14042286544
# 3  {'address1': '5436 Riverdale Rd', 'address2': ...  +16785195443
# 4  {'address1': '101 Kenwood Rd', 'address2': 'St...  +16782712011
#
#     display_phone      distance price
# 0  (404) 429-3317  24765.216688   NaN
# 1  (678) 604-6680  28783.492045   NaN
# 2  (404) 228-6544  31365.909242   NaN
# 3  (678) 519-5443  28746.707011    $$
# 4  (678) 271-2011  20018.312815   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             16 non-null     object
#  1   alias          16 non-null     object
#  2   name           16 non-null     object
#  3   image_url      16 non-null     object
#  4   is_closed      16 non-null     bool
#  5   url            16 non-null     object
#  6   review_count   16 non-null     int64
#  7   categories     16 non-null     object
#  8   rating         16 non-null     float64
#  9   coordinates    16 non-null     object
#  10  transactions   16 non-null     object
#  11  location       16 non-null     object
#  12  phone          16 non-null     object
#  13  display_phone  16 non-null     object
#  14  distance       16 non-null     float64
#  15  price          3 non-null      object
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 2.0+ KB

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Hampton-jollof.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression = 'gzip', index = False)
